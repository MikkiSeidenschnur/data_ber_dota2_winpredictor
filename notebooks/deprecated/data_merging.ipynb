# %% [markdown]
# # DEPRECATED
#
# ## The data we obtained from this api is not useful so we decided to continue to do it in other way

# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# %% [markdown]
# # Merge Data

# %% [markdown]
# **1. Find all files on rawdata folder and add it to a list**

# %%
csv_files = [f for f in listdir("../rawdata/")]

# %% [markdown]
# **2. Use pandas to merge csv files**

# %%
data = pd.DataFrame(columns=["match_id","match_seq_num", "radiant_win","start_time","duration","avg_mmr","num_mmr","lobby_type","game_mode","avg_rank_tier","num_rank_tier","cluster","radiant_team","dire_team"])

# %%
for file in csv_files:
    new = pd.read_csv(f"../rawdata/{file}")
    data = data.append(new, ignore_index=True)

# %%
data
# Out:
#           match_id match_seq_num radiant_win  start_time duration avg_mmr  \
# 0       5495833601           NaN         NaN         NaN      NaN     NaN
# 1       5495972868           NaN         NaN         NaN      NaN     NaN
# 2       5494436377           NaN         NaN         NaN      NaN     NaN
# 3       5497036314           NaN         NaN         NaN      NaN     NaN
# 4       5496854050           NaN         NaN         NaN      NaN     NaN
# ...            ...           ...         ...         ...      ...     ...
# 878695  5497386519    4608812348       False  1593787063     1672    5216
# 878696  5497388008    4608830309       False  1593787096     2328     NaN
# 878697  5497390804    4608827072       False  1593787229     2160    5218
# 878698  5497392310    4608837472       False  1593787288     2440    5131
# 878699  5497394702    4608808368        True  1593787372     1195    5093
#
#        num_mmr lobby_type game_mode avg_rank_tier num_rank_tier cluster  \
# ...
