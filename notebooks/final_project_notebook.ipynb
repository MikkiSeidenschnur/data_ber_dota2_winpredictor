# %%
import pandas as pd
import numpy as np
import requests
import json

# %% [markdown]
# ### 1. We start off by getting the matches (DO NOT RUN THIS UNLESS YOU ARE SURE)

# %%
### get_matches returns a dataframe from the opendota API with given parameters
### don't run this too often, as there is a request limit of one per second and 50000 pr. month
def get_matches(matches=10000, start_time_less_than=1594771200):
    # we build the base url for the opendota api 
    base = 'https://api.opendota.com/api/explorer'
    # we create the SQL percent encoded query. The query is as follows
    #"""
    #SELECT *
    #FROM public_matches
    #LEFT JOIN public_player_matches
    #ON public_matches.match_id = public_player_matches.match_id
    #WHERE lobby_type=7 AND game_mode=22 AND avg_mmr!=0 AND start_time<1594771200
    #ORDER BY start_time DESC
    #LIMIT 1000000
    #"""
    matches_request = f'?sql=SELECT%20*%0AFROM%20public_matches%0ALEFT%20JOIN%20public_player_matches%0AON%20public_matches.match_id%20%3D%20public_player_matches.match_id%0AWHERE%20lobby_type%3D7%20AND%20game_mode%3D22%20AND%20avg_mmr!%3D0%20AND%20start_time%3C{start_time_less_than}%0AORDER%20BY%20start_time%20DESC%0Alimit%20{str(matches)}'

    url = base + matches_request

    result = requests.get(url)
    print(result)
    j_matches = result.json()

    return pd.DataFrame(j_matches["rows"])

# %%
df_matches_response = get_matches(matches=500000, start_time_less_than=1594771200)
# Out:
# <Response [200]>

# %% [markdown]
# ### 2. Let's start inspecting our dataframe

# %% [markdown]
# **We do have to be mindful that all matches are duplicated 10 times, since there is a row for each picked hero in each match**

# %%
df_matches = df_matches_response
df_matches
# Out:
#           match_id  match_seq_num  radiant_win  start_time  duration  avg_mmr  \
# 0       5513437212     4623088705         True  1594771194      2467     3265
# 1       5513437212     4623088705         True  1594771194      2467     3265
# 2       5513437212     4623088705         True  1594771194      2467     3265
# 3       5513437212     4623088705         True  1594771194      2467     3265
# 4       5513437212     4623088705         True  1594771194      2467     3265
# ...            ...            ...          ...         ...       ...      ...
# 499995  5511875905     4621658882         True  1594676135      1853     3379
# 499996  5511875905     4621658882         True  1594676135      1853     3379
# 499997  5511875905     4621658882         True  1594676135      1853     3379
# 499998  5511875905     4621658882         True  1594676135      1853     3379
# 499999  5511875905     4621658882         True  1594676135      1853     3379
#
#         num_mmr  lobby_type  game_mode  avg_rank_tier  ...  radiant_1  \
# 0             4           7         22             61  ...        NaN
# 1             4           7         22             61  ...        NaN
# 2             4           7         22             61  ...        NaN
# 3             4           7         22             61  ...        NaN
# 4             4           7         22             61  ...        NaN
# ...         ...         ...        ...            ...  ...        ...
# 499995        1           7         22             39  ...        NaN
# 499996        1           7         22             39  ...        NaN
# 499997        1           7         22             39  ...        NaN
# 499998        1           7         22             39  ...        NaN
# 499999        1           7         22             39  ...        1.0
#
#         radiant_2  radiant_3  radiant_4  radiant_5  dire_1  dire_2  dire_3  \
# 0             NaN        NaN        NaN        NaN     NaN     NaN     NaN
# 1             NaN        NaN        NaN        NaN     NaN     NaN     NaN
# 2             NaN        NaN        NaN        NaN     NaN     NaN     1.0
# 3             NaN        NaN        NaN        NaN     NaN     1.0     NaN
# 4             NaN        NaN        NaN        NaN     1.0     NaN     NaN
# ...           ...        ...        ...        ...     ...     ...     ...
# 499995        NaN        NaN        NaN        1.0     NaN     NaN     NaN
# 499996        NaN        NaN        1.0        NaN     NaN     NaN     NaN
# 499997        NaN        1.0        NaN        NaN     NaN     NaN     NaN
# 499998        1.0        NaN        NaN        NaN     NaN     NaN     NaN
# 499999        NaN        NaN        NaN        NaN     NaN     NaN     NaN
#
#         dire_4  dire_5
# 0          NaN     1.0
# 1          1.0     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ...        ...     ...
# 499995     NaN     NaN
# 499996     NaN     NaN
# 499997     NaN     NaN
# 499998     NaN     NaN
# 499999     NaN     NaN
#
# [500000 rows x 24 columns]

# %% [markdown]
# **As seen below, all the datatypes seem to come in the right format**

# %%
df_matches.dtypes
# Out:
# match_id           int64
# match_seq_num      int64
# radiant_win         bool
# start_time         int64
# duration           int64
# avg_mmr            int64
# num_mmr            int64
# lobby_type         int64
# game_mode          int64
# avg_rank_tier      int64
# num_rank_tier      int64
# cluster            int64
# player_slot        int64
# hero_id            int64
# radiant_1        float64
# radiant_2        float64
# radiant_3        float64
# radiant_4        float64
# radiant_5        float64
# dire_1           float64
# dire_2           float64
# dire_3           float64
# dire_4           float64
# dire_5           float64
# dtype: object

# %% [markdown]
# **There are zero null values, as this was handled in the SQL query to the API**

# %%
df_matches.isna().sum()
# Out:
# match_id              0
# match_seq_num         0
# radiant_win           0
# start_time            0
# duration              0
# avg_mmr               0
# num_mmr               0
# lobby_type            0
# game_mode             0
# avg_rank_tier         0
# num_rank_tier         0
# cluster               0
# player_slot           0
# hero_id               0
# radiant_1        450000
# radiant_2        450000
# radiant_3        450000
# radiant_4        450000
# radiant_5        450000
# dire_1           450000
# dire_2           450000
# dire_3           450000
# dire_4           450000
# dire_5           450000
# dtype: int64

# %% [markdown]
# **Let's have a look at the "Player Slot" column**
#
# * 0-4: Radiant team
# * 128-132: Dire team
#
# If the player slot is between 0-4 the player is on the radiant team and if the player is in 128-132 the player is on the dire team

# %%
df_matches["player_slot"].value_counts()
# Out:
# 132    50000
# 131    50000
# 130    50000
# 129    50000
# 128    50000
# 4      50000
# 3      50000
# 2      50000
# 1      50000
# 0      50000
# Name: player_slot, dtype: int64

# %% [markdown]
# **Let's reformat that to "Radiant" and "Dire"**
#
# We do not care what slot on dire the player was located in. Therefore we simply convert it to "Radiant" and "Dire"

# %%
slot_dict = {0: "radiant_1",
             1: "radiant_2",
             2: "radiant_3",
             3: "radiant_4",
             4: "radiant_5",
             128: "dire_1",
             129: "dire_2",
             130: "dire_3",
             131: "dire_4",
             132: "dire_5"}

# %%
{slot_dict[i] for i in slot_dict}
# Out:
# {'dire_1',
#  'dire_2',
#  'dire_3',
#  'dire_4',
#  'dire_5',
#  'radiant_1',
#  'radiant_2',
#  'radiant_3',
#  'radiant_4',
#  'radiant_5'}

# %%
for slot in slot_dict:
    df_matches.loc[df_matches['player_slot'] == slot, slot_dict[slot]] = 1
df_matches.head(20)
# Out:
#       match_id  match_seq_num  radiant_win  start_time  duration  avg_mmr  \
# 0   5513437212     4623088705         True  1594771194      2467     3265
# 1   5513437212     4623088705         True  1594771194      2467     3265
# 2   5513437212     4623088705         True  1594771194      2467     3265
# 3   5513437212     4623088705         True  1594771194      2467     3265
# 4   5513437212     4623088705         True  1594771194      2467     3265
# 5   5513437212     4623088705         True  1594771194      2467     3265
# 6   5513437212     4623088705         True  1594771194      2467     3265
# 7   5513437212     4623088705         True  1594771194      2467     3265
# 8   5513437212     4623088705         True  1594771194      2467     3265
# 9   5513437212     4623088705         True  1594771194      2467     3265
# 10  5513437208     4623072527         True  1594771189      1928     4327
# 11  5513437208     4623072527         True  1594771189      1928     4327
# 12  5513437208     4623072527         True  1594771189      1928     4327
# 13  5513437208     4623072527         True  1594771189      1928     4327
# 14  5513437208     4623072527         True  1594771189      1928     4327
# 15  5513437208     4623072527         True  1594771189      1928     4327
# 16  5513437208     4623072527         True  1594771189      1928     4327
# 17  5513437208     4623072527         True  1594771189      1928     4327
# 18  5513437208     4623072527         True  1594771189      1928     4327
# 19  5513437208     4623072527         True  1594771189      1928     4327
#
#     num_mmr  lobby_type  game_mode  avg_rank_tier  ...  radiant_1  radiant_2  \
# 0         4           7         22             61  ...        NaN        NaN
# 1         4           7         22             61  ...        NaN        NaN
# 2         4           7         22             61  ...        NaN        NaN
# 3         4           7         22             61  ...        NaN        NaN
# 4         4           7         22             61  ...        NaN        NaN
# 5         4           7         22             61  ...        NaN        NaN
# 6         4           7         22             61  ...        NaN        NaN
# 7         4           7         22             61  ...        NaN        NaN
# 8         4           7         22             61  ...        NaN        1.0
# 9         4           7         22             61  ...        1.0        NaN
# 10        2           7         22             37  ...        NaN        NaN
# 11        2           7         22             37  ...        NaN        NaN
# 12        2           7         22             37  ...        NaN        NaN
# 13        2           7         22             37  ...        NaN        NaN
# 14        2           7         22             37  ...        NaN        NaN
# 15        2           7         22             37  ...        NaN        NaN
# 16        2           7         22             37  ...        NaN        NaN
# 17        2           7         22             37  ...        NaN        NaN
# 18        2           7         22             37  ...        NaN        1.0
# 19        2           7         22             37  ...        1.0        NaN
#
#     radiant_3  radiant_4  radiant_5  dire_1  dire_2  dire_3  dire_4  dire_5
# 0         NaN        NaN        NaN     NaN     NaN     NaN     NaN     1.0
# 1         NaN        NaN        NaN     NaN     NaN     NaN     1.0     NaN
# 2         NaN        NaN        NaN     NaN     NaN     1.0     NaN     NaN
# 3         NaN        NaN        NaN     NaN     1.0     NaN     NaN     NaN
# 4         NaN        NaN        NaN     1.0     NaN     NaN     NaN     NaN
# 5         NaN        NaN        1.0     NaN     NaN     NaN     NaN     NaN
# 6         NaN        1.0        NaN     NaN     NaN     NaN     NaN     NaN
# 7         1.0        NaN        NaN     NaN     NaN     NaN     NaN     NaN
# 8         NaN        NaN        NaN     NaN     NaN     NaN     NaN     NaN
# 9         NaN        NaN        NaN     NaN     NaN     NaN     NaN     NaN
# 10        NaN        NaN        NaN     NaN     NaN     NaN     NaN     1.0
# 11        NaN        NaN        NaN     NaN     NaN     NaN     1.0     NaN
# 12        NaN        NaN        NaN     NaN     NaN     1.0     NaN     NaN
# 13        NaN        NaN        NaN     NaN     1.0     NaN     NaN     NaN
# 14        NaN        NaN        NaN     1.0     NaN     NaN     NaN     NaN
# 15        NaN        NaN        1.0     NaN     NaN     NaN     NaN     NaN
# 16        NaN        1.0        NaN     NaN     NaN     NaN     NaN     NaN
# 17        1.0        NaN        NaN     NaN     NaN     NaN     NaN     NaN
# 18        NaN        NaN        NaN     NaN     NaN     NaN     NaN     NaN
# 19        NaN        NaN        NaN     NaN     NaN     NaN     NaN     NaN
#
# [20 rows x 24 columns]

# %%
df_matches["player_slot"].value_counts()
# Out:
# 132    50000
# 131    50000
# 130    50000
# 129    50000
# 128    50000
# 4      50000
# 3      50000
# 2      50000
# 1      50000
# 0      50000
# Name: player_slot, dtype: int64

# %% [markdown]
# Since there is an equal amount of heroes on each side, this means that we split it correctly

# %%
df_matches.rename(columns={"player_slot": "team"})
# Out:
#           match_id  match_seq_num  radiant_win  start_time  duration  avg_mmr  \
# 0       5513437212     4623088705         True  1594771194      2467     3265
# 1       5513437212     4623088705         True  1594771194      2467     3265
# 2       5513437212     4623088705         True  1594771194      2467     3265
# 3       5513437212     4623088705         True  1594771194      2467     3265
# 4       5513437212     4623088705         True  1594771194      2467     3265
# ...            ...            ...          ...         ...       ...      ...
# 499995  5511875905     4621658882         True  1594676135      1853     3379
# 499996  5511875905     4621658882         True  1594676135      1853     3379
# 499997  5511875905     4621658882         True  1594676135      1853     3379
# 499998  5511875905     4621658882         True  1594676135      1853     3379
# 499999  5511875905     4621658882         True  1594676135      1853     3379
#
#         num_mmr  lobby_type  game_mode  avg_rank_tier  num_rank_tier  cluster  \
# 0             4           7         22             61              6      154
# 1             4           7         22             61              6      154
# 2             4           7         22             61              6      154
# 3             4           7         22             61              6      154
# 4             4           7         22             61              6      154
# ...         ...         ...        ...            ...            ...      ...
# 499995        1           7         22             39              4      183
# 499996        1           7         22             39              4      183
# 499997        1           7         22             39              4      183
# 499998        1           7         22             39              4      183
# 499999        1           7         22             39              4      183
#
#            team  hero_id
# 0          Dire       84
# 1          Dire        8
# 2          Dire       39
# 3          Dire       29
# 4          Dire       80
# ...         ...      ...
# 499995  Radiant       29
# 499996  Radiant       36
# 499997  Radiant       21
# 499998  Radiant       56
# 499999  Radiant      105
#
# [500000 rows x 14 columns]

# %% [markdown]
# **We do not care about `[num_mmr, lobby_type, game_mode, avg_rank_tier]`, so these columns are dropped**

# %%
df_matches.drop(["num_mmr", "lobby_type", "game_mode", "avg_rank_tier"], axis=1, inplace=True)

# %%
df_matches.head(10)
# Out:
#      match_id  match_seq_num  radiant_win  start_time  duration  avg_mmr  \
# 0  5513437212     4623088705         True  1594771194      2467     3265
# 1  5513437212     4623088705         True  1594771194      2467     3265
# 2  5513437212     4623088705         True  1594771194      2467     3265
# 3  5513437212     4623088705         True  1594771194      2467     3265
# 4  5513437212     4623088705         True  1594771194      2467     3265
# 5  5513437212     4623088705         True  1594771194      2467     3265
# 6  5513437212     4623088705         True  1594771194      2467     3265
# 7  5513437212     4623088705         True  1594771194      2467     3265
# 8  5513437212     4623088705         True  1594771194      2467     3265
# 9  5513437212     4623088705         True  1594771194      2467     3265
#
#    num_rank_tier  cluster player_slot  hero_id
# 0              6      154        Dire       84
# 1              6      154        Dire        8
# 2              6      154        Dire       39
# 3              6      154        Dire       29
# 4              6      154        Dire       80
# 5              6      154     Radiant       46
# 6              6      154     Radiant       75
# 7              6      154     Radiant       96
# 8              6      154     Radiant        4
# 9              6      154     Radiant       25

# %% [markdown]
# **We want to go from this table:**
#
# | match_id | ... | player_slot | hero_id |
# |------|------|------|------|
# |5513437212|...|Dire|84|
# |5513437212|...|Dire|8|
# |5513437212|...|Dire|39|
# |5513437212|...|Dire|29|
# |5513437212|...|Dire|80|
# |5513437212|...|Radiant|46|
# |5513437212|...|Radiant|75|
# |5513437212|...|Radiant|96|
# |5513437212|...|Radiant|4|
# |5513437212|...|Radiant|25|
#
# **To this table:**
#
# | match_id | ... | radiant1 | radiant2 | radiant3 | radiant4 | radiant5 |  dire1 | dire2 | dire3 | dire4 | dire5 |
# |------|------|------|------|------|------|------|------|------|------|------|------|
# |5513437212|...|46|75|96|4|25|84|8|39|29|80|
